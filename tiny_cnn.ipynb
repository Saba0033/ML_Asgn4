# %% [markdown]
# # TinyCNN
#
# 2 conv blocks. should be better than MLP.

# %%
import sys
sys.path.append(".")

from src import notebook_utils as nu

nu.setup()

grid = [
    {"note": "underfit", "model": {"width": 8,  "dropout": 0.5}, "train": {"epochs": 20, "lr": 1e-3}},
    {"note": "wellfit_a", "model": {"width": 32, "dropout": 0.3}, "train": {"epochs": 20, "lr": 1e-3}},
    {"note": "wellfit_b", "model": {"width": 64, "dropout": 0.3}, "train": {"epochs": 20, "lr": 1e-3}},
    {"note": "overfit",  "model": {"width": 64, "dropout": 0.0}, "train": {"epochs": 20, "lr": 1e-3}},
    {"note": "lr_high", "model": {"width": 32, "dropout": 0.3}, "train": {"epochs": 20, "lr": 1e-2}},
]

nu.run_architecture(
    "TinyCNN",
    grid=grid,
    final_train={"epochs": 40},
    plot=("TinyCNN", "tinycnn_curves.png"),
    augment=False,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sekhv23 (sekhv23-free-university-of-tbilisi) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# TinyCNN: output (128, 7), loss=1.948
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.27.2
# ...
