# %% [markdown]
# # DeepCNN
#
# deeper CNN. augmentation on, class weights. ablation = with/without aug.

# %%
import sys
sys.path.append(".")

from src import notebook_utils as nu

nu.setup()

grid = [
    {"note": "underfit_1blk", "model": {"n_blocks": 1, "base_width": 32, "use_bn": False, "dropout": 0.5}, "train": {"epochs": 25, "lr": 1e-3}},
    {"note": "2blk_bn",       "model": {"n_blocks": 2, "base_width": 64, "use_bn": True,  "dropout": 0.3}, "train": {"epochs": 25, "lr": 1e-3}},
    {"note": "3blk_bn_drop",  "model": {"n_blocks": 3, "base_width": 64, "use_bn": True,  "dropout": 0.4}, "train": {"epochs": 25, "lr": 1e-3, "weight_decay": 1e-4}},
    {"note": "overfit_noreg", "model": {"n_blocks": 3, "base_width": 64, "use_bn": False, "dropout": 0.0}, "train": {"epochs": 25, "lr": 1e-3}},
]

nu.run_architecture(
    "DeepCNN",
    grid=grid,
    final_train={"epochs": 60, "scheduler": "cosine", "label_smoothing": 0.05, "patience": 12},
    plot=("DeepCNN", "deepcnn_curves.png"),
    augment=True,
    class_weights_on=True,
    ablation={
        "model": {"n_blocks": 3, "base_width": 64, "use_bn": True, "dropout": 0.0},
        "train": {"epochs": 25, "lr": 1e-3},
    },
)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sekhv23 (sekhv23-free-university-of-tbilisi) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# DeepCNN: output (128, 7), loss=1.947
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.27.2
# ...
